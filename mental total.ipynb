# %%
#IMPORTING DATASET(.CSV) INTO PANDAS DATAFRAME
import alt as alt
import pandas as pd

dataset1 = pd.read_csv('01_april_30_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')
dataset1.columns = map(str.upper, dataset1.columns)

dataset2 = pd.read_csv('02_May_12_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')

dataset3 = pd.read_csv('03_june_9_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')
dataset3.columns = map(str.upper, dataset3.columns)

#Selected Features
selected_features = [
                      'SOC5A','SOC5B','SOC5C','SOC5D','SOC5E'
                      ]


df1 = dataset1[selected_features]
df1.dropna(inplace=True)
df2 = dataset2[selected_features]
df2.dropna(inplace=True)
df3 = dataset3[selected_features]
df3.dropna(inplace=True)

df = df1.append(df2,ignore_index = True).append(df3,ignore_index = True)
# df.isna().sum()

#Exporting Selected Features from datasets
from pathlib import Path

filepath1 = Path('C:\python\df1.csv')
filepath1.parent.mkdir(parents=True, exist_ok=True)
df1.to_csv(filepath1)

filepath2 = Path('C:\python\df2.csv')
filepath2.parent.mkdir(parents=True, exist_ok=True)
df2.to_csv(filepath2)

filepath3 = Path('C:\python\df3.csv')
filepath3.parent.mkdir(parents=True, exist_ok=True)
df3.to_csv(filepath3)

filepath = Path('C:\python\df.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(filepath)
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_14008\716147559.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_14008\716147559.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_14008\716147559.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df1.drop(df1.loc[df1['SOC5A']== '(98) SKIPPED ON WEB'].index, inplace=True)
df1.drop(df1.loc[df1['SOC5B']== '(98) SKIPPED ON WEB'].index, inplace=True)
df1.drop(df1.loc[df1['SOC5C']== '(98) SKIPPED ON WEB'].index, inplace=True)
df1.drop(df1.loc[df1['SOC5D']== '(98) SKIPPED ON WEB'].index, inplace=True)
df1.drop(df1.loc[df1['SOC5E']== '(98) SKIPPED ON WEB'].index, inplace=True)
df1.drop(df1.loc[df1['SOC5A']== "(77) DON'T KNOW"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5B']== "(77) DON'T KNOW"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5C']== "(77) DON'T KNOW"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5D']== "(77) DON'T KNOW"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5E']== "(77) DON'T KNOW"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5A']== "(99) REFUSED"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5B']== "(99) REFUSED"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5C']== "(99) REFUSED"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5D']== "(99) REFUSED"].index, inplace=True)
df1.drop(df1.loc[df1['SOC5E']== "(99) REFUSED"].index, inplace=True)

df2.drop(df2.loc[df2['SOC5A']== '(98) SKIPPED ON WEB'].index, inplace=True)
df2.drop(df2.loc[df2['SOC5B']== '(98) SKIPPED ON WEB'].index, inplace=True)
df2.drop(df2.loc[df2['SOC5C']== '(98) SKIPPED ON WEB'].index, inplace=True)
df2.drop(df2.loc[df2['SOC5D']== '(98) SKIPPED ON WEB'].index, inplace=True)
df2.drop(df2.loc[df2['SOC5E']== '(98) SKIPPED ON WEB'].index, inplace=True)
df2.drop(df2.loc[df2['SOC5A']== "(77) DON'T KNOW"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5B']== "(77) DON'T KNOW"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5C']== "(77) DON'T KNOW"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5D']== "(77) DON'T KNOW"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5E']== "(77) DON'T KNOW"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5A']== "(99) REFUSED"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5B']== "(99) REFUSED"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5C']== "(99) REFUSED"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5D']== "(99) REFUSED"].index, inplace=True)
df2.drop(df2.loc[df2['SOC5E']== "(99) REFUSED"].index, inplace=True)

df3.drop(df3.loc[df3['SOC5A']== '(98) SKIPPED ON WEB'].index, inplace=True)
df3.drop(df3.loc[df3['SOC5B']== '(98) SKIPPED ON WEB'].index, inplace=True)
df3.drop(df3.loc[df3['SOC5C']== '(98) SKIPPED ON WEB'].index, inplace=True)
df3.drop(df3.loc[df3['SOC5D']== '(98) SKIPPED ON WEB'].index, inplace=True)
df3.drop(df3.loc[df3['SOC5E']== '(98) SKIPPED ON WEB'].index, inplace=True)
df3.drop(df3.loc[df3['SOC5A']== "(77) DON'T KNOW"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5B']== "(77) DON'T KNOW"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5C']== "(77) DON'T KNOW"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5D']== "(77) DON'T KNOW"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5E']== "(77) DON'T KNOW"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5A']== "(99) REFUSED"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5B']== "(99) REFUSED"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5C']== "(99) REFUSED"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5D']== "(99) REFUSED"].index, inplace=True)
df3.drop(df3.loc[df3['SOC5E']== "(99) REFUSED"].index, inplace=True)
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_14008\267175659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.loc[df1['SOC5A']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_14008\267175659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.loc[df1['SOC5B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_14008\267175659.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
input = ['SOC5A']
# input= selected_features
output = pd.DataFrame([])
for i in range(len(input)):
    # print(df1[input[i]].value_counts())
    data1=[]
    data2=[]
    data3=[]
    data=[]


    feature1 = df1[input[i]]
    data1=feature1.value_counts()\
        .rename_axis('unique_values')\
        .reset_index(name='1st survey')\
        .sort_values('unique_values')\
        .reset_index(drop=True)

    data11=feature1.value_counts(normalize=True)\
        .rename_axis('unique_values')\
        .reset_index(name='1st survey %')\
        .sort_values('unique_values')\
        .reset_index(drop=True)

    feature2 = df2[input[i]]
    data2=feature2.value_counts()\
        .rename_axis('unique_values')\
        .reset_index(name='2nd survey')\
        .sort_values('unique_values')\
        .reset_index(drop=True)

    data22=feature2.value_counts(normalize=True)\
        .rename_axis('unique_values')\
        .reset_index(name='2nd survey %')\
        .sort_values('unique_values')\
        .reset_index(drop=True)

    feature3 = df3[input[i]]
    data3=feature3.value_counts()\
        .rename_axis('unique_values')\
        .reset_index(name='3rd survey')\
        .sort_values('unique_values')\
        .reset_index(drop=True)

    data33=feature3.value_counts(normalize=True)\
        .rename_axis('unique_values')\
        .reset_index(name='3rd survey %')\
        .sort_values('unique_values')\
        .reset_index(drop=True)

    data = pd.concat([data1,
                      data11['1st survey %'],
                      data2['2nd survey'],
                      data22['2nd survey %'],
                      data3['3rd survey'],
                      data33['3rd survey %']],
                     axis = 1)

    data.drop(data.tail(1).index,inplace=True)
    output = output.append(data)

filepath = Path('C:\python\out2.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
output.to_csv(filepath)
output
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_14008\3492308368.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(data)
#                        unique_values  1st survey  1st survey %  2nd survey  \
# 0  (1) Not at all or less than 1 day        5357      0.619880        5598
# 1                       (2) 1-2 days        1869      0.216269        1958
# 2                       (3) 3-4 days         793      0.091761         782
#
#    2nd survey %  3rd survey  3rd survey %
# 0      0.634119        4549      0.616396
# 1      0.221794        1616      0.218970
# 2      0.088582         703      0.095257

# %%
feature3.value_counts()
# Out:
# (1) Not at all or less than 1 day    4549
# (2) 1-2 days                         1616
# (3) 3-4 days                          703
# (4) 5-7 days                          512
# Name: SOC5A, dtype: int64
