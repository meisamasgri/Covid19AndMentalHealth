# %%
#IMPORTING DATASET(.CSV) INTO PANDAS DATAFRAME
import alt as alt
import pandas as pd

dataset1 = pd.read_csv('01_april_30_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')
dataset1.columns = map(str.upper, dataset1.columns)

dataset2 = pd.read_csv('02_May_12_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')

dataset3 = pd.read_csv('03_june_9_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')
dataset3.columns = map(str.upper, dataset3.columns)

#Selected Features
selected_features = ['SOC1','SOC2A','SOC2B','SOC3A','SOC3B','SOC4A','SOC4B',
                      'SOC5A','SOC5B','SOC5C','SOC5D','SOC5E',
                      'PHYS1A','PHYS1B','PHYS1C','PHYS1D','PHYS1E','PHYS1F','PHYS1G','PHYS1H','PHYS1I','PHYS1J','PHYS1K','PHYS1L','PHYS1M','PHYS1N','PHYS1O','PHYS1P','PHYS1Q',
                      'PHYS2_1','PHYS2_2','PHYS2_3','PHYS2_4','PHYS2_5','PHYS2_6','PHYS2_7','PHYS2_8','PHYS2_9','PHYS2_10','PHYS2_11','PHYS2_12','PHYS2_13','PHYS2_14','PHYS2_15','PHYS2_16','PHYS2_17','PHYS2_18','PHYS2_19',
                      'PHYS7_1','PHYS7_2','PHYS7_3','PHYS7_4',
                      'PHYS8',
                      'PHYS10A','PHYS10B','PHYS10C','PHYS10D','PHYS10E',
                      'AGE7','GENDER','RACETH','ECON4A','ECON4B','HHINCOME','EDUCATION','HHSIZE1','HH_BANNER',
                      ]


df1 = dataset1[selected_features]
df1.dropna(inplace=True)
df2 = dataset2[selected_features]
df2.dropna(inplace=True)
df3 = dataset3[selected_features]
df3.dropna(inplace=True)

df = df1.append(df2,ignore_index = True).append(df3,ignore_index = True)
# df.isna().sum()

#Exporting Selected Features from datasets
from pathlib import Path

filepath1 = Path('C:\python\df1.csv')
filepath1.parent.mkdir(parents=True, exist_ok=True)
df1.to_csv(filepath1)

filepath2 = Path('C:\python\df2.csv')
filepath2.parent.mkdir(parents=True, exist_ok=True)
df2.to_csv(filepath2)

filepath3 = Path('C:\python\df3.csv')
filepath3.parent.mkdir(parents=True, exist_ok=True)
df3.to_csv(filepath3)

filepath = Path('C:\python\df.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(filepath)

#SE1: Changes in Social Relationships Before(SOC2B) and After(SOC2A) Covid Pandemic
import matplotlib.pyplot as plt
import seaborn as sns
SE1 = pd.crosstab(df['SOC3B'],
                  df['SOC3A'],
                 margins = False)

fig, ax = plt.subplots(figsize=(10, 10))
s= sns.heatmap(SE1, annot=True,fmt='g')
s.set(xlabel='Social Media (After Covid Pandemic)', ylabel='Social Media (Before Covid Pandemic')
plt.savefig("C:\python\SE03-CROSS.png",
            format='png',
            dpi=600,
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\4134898005.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\4134898005.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\4134898005.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.dropna(inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\4134898005.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2,ignore_index = True).append(df3,ignore_index = True)

# %%
import numpy as np

################################################################
######################    GENDER        ########################
################################################################

se2_sex=df[['SOC2B','SOC2A','GENDER']]

se2_sex.drop(se2_sex.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['GENDER']== '(98) SKIPPED ON WEB'].index, inplace=True)

se2_sex['SOC2B']=se2_sex['SOC2B'].str[1:]
se2_sex['SOC2B'] = se2_sex['SOC2B'].str.split(')').str[0].astype(int)
se2_sex['SOC2A']=se2_sex['SOC2A'].str[1:]
se2_sex['SOC2A'] = se2_sex['SOC2A'].str.split(')').str[0].astype(int)

ticks = se2_sex['GENDER'].sort_values().unique();
cols = se2_sex['GENDER'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_sex['GENDER'] == cols[i]
    data_b.append(se2_sex[mask]['SOC2B'])
    data_a.append(se2_sex[mask]['SOC2A'])

fig, axs = plt.subplots(2, 3, constrained_layout=True,figsize=(15, 8))
# fig = plt.figure(figsize=(15, 8))
plt.sca(axs[0,0])
plt.title('(a) Gender')
plt.sca(axs[0,1])
plt.title('(b) Age')
plt.sca(axs[0,2])
plt.title('(c) Income')
plt.sca(axs[1,0])
plt.title('(d) Education')
plt.sca(axs[1,1])
plt.title('(e) Race')
plt.sca(axs[1,2])
plt.title('(f) Trust People in Neighborhood')

plt.suptitle('Activation functions')



plt.subplot(2,3,1)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=max 5=min')
# plt.xlabel('sex')
# plt.title('Gender')
# axs[0].xlabel('Gender')
plt.xticks(fontsize=7 , rotation=45)
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 6)
plt.tight_layout()
# plt.savefig('C:\python\se2-sex.png',format='png', dpi=600)


################################################################
######################      AGE         ########################
################################################################

se2_age=df[['SOC2B','SOC2A','AGE7']]

se2_age.drop(se2_age.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
se2_age.drop(se2_age.loc[df['AGE7']== '(88) Removed for disclosure risk'].index, inplace=True)
# df['AGE7'] = df['AGE7'].replace(['Under $10,000'],'1-$<10K')


se2_age['SOC2B']=se2_age['SOC2B'].str[1:]
se2_age['SOC2B'] = se2_age['SOC2B'].str.split(')').str[0].astype(int)
se2_age['SOC2A']=se2_age['SOC2A'].str[1:]
se2_age['SOC2A'] = se2_age['SOC2A'].str.split(')').str[0].astype(int)

ticks = se2_age['AGE7'].sort_values().unique();
cols = se2_age['AGE7'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_age['AGE7'] == cols[i]
    data_b.append(se2_age[mask]['SOC2B'])
    data_a.append(se2_age[mask]['SOC2A'])

plt.subplot(2,3,2)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_a)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_b)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=max 5=min')
# plt.xlabel('Age')
# plt.title('Age')
plt.xticks(fontsize=7 , rotation=45)
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 6)
plt.tight_layout()
# plt.savefig('C:\python\se2-age.png',format='png', dpi=600)


################################################################
######################    INCOME        ########################
################################################################


se2_inc=df[['SOC2B','SOC2A','HHINCOME']]

# se2_inc['HHINCOME'].unique()

se2_inc.drop(se2_inc.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['HHINCOME']== 'REFUSED'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['HHINCOME']== 'SKIPPED ON WEB'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['HHINCOME']== "DON'T KNOW"].index, inplace=True)
df['HHINCOME'] = df['HHINCOME'].replace(['Under $10,000'],'(1) $<10K')
df['HHINCOME'] = df['HHINCOME'].replace(['$10,000 to under $20,000'],'(2) 10K<$<20K')
df['HHINCOME'] = df['HHINCOME'].replace(['$20,000 to under $30,000'],'(3) 20K<$<30K')
df['HHINCOME'] = df['HHINCOME'].replace(['$30,000 to under $40,000'],'(4) 30K<$<40K')
df['HHINCOME'] = df['HHINCOME'].replace(['$40,000 to under $50,000'],'(5) 40K<$<50K')
df['HHINCOME'] = df['HHINCOME'].replace(['$50,000 to under $75,000'],'(6) 50K<$<75K')
df['HHINCOME'] = df['HHINCOME'].replace(['$75,000 to under $100,000'],'(7) 75K<$<100K')
df['HHINCOME'] = df['HHINCOME'].replace(['$100,000 to under $150,000'],'(8) 100K<$<150K')
df['HHINCOME'] = df['HHINCOME'].replace(['$150,000 or more'],'(9) $>150K')



se2_inc['SOC2B']=se2_inc['SOC2B'].str[1:]
se2_inc['SOC2B'] = se2_inc['SOC2B'].str.split(')').str[0].astype(int)
se2_inc['SOC2A']=se2_inc['SOC2A'].str[1:]
se2_inc['SOC2A'] = se2_inc['SOC2A'].str.split(')').str[0].astype(int)

ticks = se2_inc['HHINCOME'].sort_values().unique()
cols = se2_inc['HHINCOME'].unique()
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_inc['HHINCOME'] == cols[i]
    data_b.append(se2_inc[mask]['SOC2B'])
    data_a.append(se2_inc[mask]['SOC2A'])

plt.subplot(2,3,3)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=max 5=min')
# plt.xlabel('inc')
plt.xticks(fontsize=7 , rotation=45)
# plt.title('Income')


plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 6)
plt.tight_layout()
# plt.savefig('C:\python\se2-inc.png',format='png', dpi=600)


################################################################
######################    EDUCATION     ########################
################################################################

se2_edu=df[['SOC2B','SOC2A','EDUCATION']]

se2_edu['EDUCATION'].unique()


se2_edu.drop(se2_edu.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(99) REFUSED'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(77) Not sure'].index, inplace=True)
df['EDUCATION'] = df['EDUCATION'].replace(['(2) HIGH SCHOOL GRADUATE - high school DIPLOMA or the equivalent (GED)'],'(2) HIGH SCHOOL GRADUATE')


se2_edu['SOC2B']=se2_edu['SOC2B'].str[1:]
se2_edu['SOC2B'] = se2_edu['SOC2B'].str.split(')').str[0].astype(int)
se2_edu['SOC2A']=se2_edu['SOC2A'].str[1:]
se2_edu['SOC2A'] = se2_edu['SOC2A'].str.split(')').str[0].astype(int)

ticks = se2_edu['EDUCATION'].sort_values().unique();
cols = se2_edu['EDUCATION'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_edu['EDUCATION'] == cols[i]
    data_b.append(se2_edu[mask]['SOC2B'])
    data_a.append(se2_edu[mask]['SOC2A'])

plt.subplot(2,3,4)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=max 5=min')
# plt.xlabel('edu')
plt.xticks(fontsize=7 , rotation=45)
# plt.title('Education')

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 6)
plt.tight_layout()
# plt.savefig('C:\python\se2-edu.png',format='png', dpi=600)




################################################################
######################        RACE      ########################
################################################################

se2_rac=df[['SOC2B','SOC2A','RACETH']]

se2_rac['RACETH'].unique()


se2_rac.drop(se2_rac.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['RACETH']== '(99) REFUSED'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['RACETH']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['RACETH']== "(77) DON'T KNOW"].index, inplace=True)

se2_rac['SOC2B']=se2_rac['SOC2B'].str[1:]
se2_rac['SOC2B'] = se2_rac['SOC2B'].str.split(')').str[0].astype(int)
se2_rac['SOC2A']=se2_rac['SOC2A'].str[1:]
se2_rac['SOC2A'] = se2_rac['SOC2A'].str.split(')').str[0].astype(int)

ticks = se2_rac['RACETH'].sort_values().unique();
cols = se2_rac['RACETH'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_rac['RACETH'] == cols[i]
    data_b.append(se2_rac[mask]['SOC2B'])
    data_a.append(se2_rac[mask]['SOC2A'])

plt.subplot(2,3,5)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=max 5=min')
# plt.xlabel('rac')
plt.xticks(fontsize=7 , rotation=45)
# plt.title('Race')

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 6)
plt.tight_layout()
# plt.savefig('C:\python\se2-rac.png',format='png', dpi=600)


################################################################
######################        SOC1      ########################
################################################################

se2_soc=df[['SOC2B','SOC2A','SOC1']]

se2_soc['SOC1'].unique()


se2_soc.drop(se2_soc.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC1']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC1']== "(77) DON'T KNOW"].index, inplace=True)

se2_soc['SOC2B']=se2_soc['SOC2B'].str[1:]
se2_soc['SOC2B'] = se2_soc['SOC2B'].str.split(')').str[0].astype(int)
se2_soc['SOC2A']=se2_soc['SOC2A'].str[1:]
se2_soc['SOC2A'] = se2_soc['SOC2A'].str.split(')').str[0].astype(int)

ticks = se2_soc['SOC1'].sort_values().unique();
cols = se2_soc['SOC1'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_soc['SOC1'] == cols[i]
    data_b.append(se2_soc[mask]['SOC2B'])
    data_a.append(se2_soc[mask]['SOC2A'])


plt.subplot(2,3,6)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=max 5=min')
# plt.xlabel('soc')
plt.xticks(fontsize=7 , rotation=45)
# plt.title('Trust people in your neighborhood')





plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 6)
plt.tight_layout()
# plt.savefig('C:\python\se2-soc.png',format='png', dpi=600)

fig.suptitle('Changes in social relationships due to Covid-19 pandemic', fontsize=16)

fig.savefig('C:\python\SE2.png',format='png', dpi=600)
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['GENDER']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex['SOC2B']=se2_sex['SOC2B'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex['SOC2B'] = se2_sex['SOC2B'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex['SOC2A']=se2_sex['SOC2A'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex['SOC2A'] = se2_sex['SOC2A'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:93: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.tight_layout()
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age.drop(se2_age.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age.drop(se2_age.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age.drop(se2_age.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age.drop(se2_age.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age.drop(se2_age.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age.drop(se2_age.loc[df['AGE7']== '(88) Removed for disclosure risk'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age['SOC2B']=se2_age['SOC2B'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age['SOC2B'] = se2_age['SOC2B'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age['SOC2A']=se2_age['SOC2A'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_age['SOC2A'] = se2_age['SOC2A'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:185: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['HHINCOME']== 'REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['HHINCOME']== 'SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc.drop(se2_inc.loc[df['HHINCOME']== "DON'T KNOW"].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc['SOC2B']=se2_inc['SOC2B'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc['SOC2B'] = se2_inc['SOC2B'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc['SOC2A']=se2_inc['SOC2A'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_inc['SOC2A'] = se2_inc['SOC2A'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:276: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:277: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:278: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:279: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(99) REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:285: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu['SOC2B']=se2_edu['SOC2B'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu['SOC2B'] = se2_edu['SOC2B'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu['SOC2A']=se2_edu['SOC2A'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_edu['SOC2A'] = se2_edu['SOC2A'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:358: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:359: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:360: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:361: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['SOC2A']== '(99) REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:363: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['RACETH']== '(99) REFUSED'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:364: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['RACETH']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:365: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac.drop(se2_rac.loc[df['RACETH']== "(77) DON'T KNOW"].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac['SOC2B']=se2_rac['SOC2B'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac['SOC2B'] = se2_rac['SOC2B'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac['SOC2A']=se2_rac['SOC2A'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:370: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_rac['SOC2A'] = se2_rac['SOC2A'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc.drop(se2_soc.loc[df['SOC2B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:439: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc.drop(se2_soc.loc[df['SOC2B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:440: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc.drop(se2_soc.loc[df['SOC2A']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc.drop(se2_soc.loc[df['SOC2A']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc.drop(se2_soc.loc[df['SOC1']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc.drop(se2_soc.loc[df['SOC1']== "(77) DON'T KNOW"].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:445: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc['SOC2B']=se2_soc['SOC2B'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:446: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc['SOC2B'] = se2_soc['SOC2B'].str.split(')').str[0].astype(int)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:447: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc['SOC2A']=se2_soc['SOC2A'].str[1:]
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21480\1353425393.py:448: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_soc['SOC2A'] = se2_soc['SOC2A'].str.split(')').str[0].astype(int)

# %%
df['AGE7'].unique()
# Out:
# array(['(3) 35-44', '(6) 65-74', '(2) 25-34', '(4) 45-54', '(5) 55-64',
#        '(1) 18-24', '(7) 75+', '(88) Removed for disclosure risk'],
#       dtype=object)
