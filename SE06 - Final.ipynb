# %%
#IMPORTING DATASET(.CSV) INTO PANDAS DATAFRAME
import alt as alt
import pandas as pd

dataset1 = pd.read_csv('01_april_30_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')
dataset1.columns = map(str.upper, dataset1.columns)

dataset2 = pd.read_csv('02_May_12_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')

dataset3 = pd.read_csv('03_june_9_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')
dataset3.columns = map(str.upper, dataset3.columns)

#Selected Features
selected_features = ['SOC1','SOC2A','SOC2B','SOC3A','SOC3B','SOC4A','SOC4B',
                      'SOC5A','SOC5B','SOC5C','SOC5D','SOC5E',
                      'PHYS1A','PHYS1B','PHYS1C','PHYS1D','PHYS1E','PHYS1F','PHYS1G','PHYS1H','PHYS1I','PHYS1J','PHYS1K','PHYS1L','PHYS1M','PHYS1N','PHYS1O','PHYS1P','PHYS1Q',
                      'PHYS2_1','PHYS2_2','PHYS2_3','PHYS2_4','PHYS2_5','PHYS2_6','PHYS2_7','PHYS2_8','PHYS2_9','PHYS2_10','PHYS2_11','PHYS2_12','PHYS2_13','PHYS2_14','PHYS2_15','PHYS2_16','PHYS2_17','PHYS2_18','PHYS2_19',
                      'PHYS7_1','PHYS7_2','PHYS7_3','PHYS7_4',
                      'PHYS8',
                      'PHYS10A','PHYS10B','PHYS10C','PHYS10D','PHYS10E',
                      'AGE7','GENDER','RACETH','ECON4A','ECON4B','HHINCOME','EDUCATION','HHSIZE1','HH_BANNER',
                      ]


df1 = dataset1[selected_features]
df1.dropna(inplace=True)
df2 = dataset2[selected_features]
df2.dropna(inplace=True)
df3 = dataset3[selected_features]
df3.dropna(inplace=True)

df = df1.append(df2,ignore_index = True).append(df3,ignore_index = True)
# df.isna().sum()

#Exporting Selected Features from datasets
from pathlib import Path

filepath1 = Path('C:\python\df1.csv')
filepath1.parent.mkdir(parents=True, exist_ok=True)
df1.to_csv(filepath1)

filepath2 = Path('C:\python\df2.csv')
filepath2.parent.mkdir(parents=True, exist_ok=True)
df2.to_csv(filepath2)

filepath3 = Path('C:\python\df3.csv')
filepath3.parent.mkdir(parents=True, exist_ok=True)
df3.to_csv(filepath3)

filepath = Path('C:\python\df.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(filepath)

#SE1: Changes in Social Relationships Before(SOC2B) and After(SOC2A) Covid Pandemic
import matplotlib.pyplot as plt
import seaborn as sns
SE1 = pd.crosstab(df['SOC3B'],
                  df['SOC3A'],
                 margins = False)

fig, ax = plt.subplots(figsize=(10, 10))
s= sns.heatmap(SE1, annot=True,fmt='g')
s.set(xlabel='Social Media (After Covid Pandemic)', ylabel='Social Media (Before Covid Pandemic')
plt.savefig("C:\python\SE03-CROSS.png",
            format='png',
            dpi=600,
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21544\4134898005.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21544\4134898005.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21544\4134898005.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import numpy as np

################################################################
######################    GENDER        ########################
################################################################

se6_sex=df[['SOC4B','SOC4A','GENDER']]

se6_sex.drop(se6_sex.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se6_sex.drop(se6_sex.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_sex.drop(se6_sex.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se6_sex.drop(se6_sex.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_sex.drop(se6_sex.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se6_sex.drop(se6_sex.loc[df['GENDER']== '(98) SKIPPED ON WEB'].index, inplace=True)

se6_sex['SOC4B']=se6_sex['SOC4B'].str[1:]
se6_sex['SOC4B'] = se6_sex['SOC4B'].str.split(')').str[0].astype(int)
se6_sex['SOC4A']=se6_sex['SOC4A'].str[1:]
se6_sex['SOC4A'] = se6_sex['SOC4A'].str.split(')').str[0].astype(int)

ticks = se6_sex['GENDER'].sort_values().unique();
cols = se6_sex['GENDER'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se6_sex['GENDER'] == cols[i]
    data_b.append(se6_sex[mask]['SOC4B'])
    data_a.append(se6_sex[mask]['SOC4A'])

fig, axs = plt.subplots(2, 3, constrained_layout=True,figsize=(15, 8))
# fig = plt.figure(figsize=(15, 8))
plt.sca(axs[0,0])
plt.title('(a) Gender')
plt.sca(axs[0,1])
plt.title('(b) Age')
plt.sca(axs[0,2])
plt.title('(c) Income')
plt.sca(axs[1,0])
plt.title('(d) Education')
plt.sca(axs[1,1])
plt.title('(e) Race')
plt.sca(axs[1,2])
plt.title('(f) Trust People in Neighborhood')

plt.suptitle('Activation functions')


plt.subplot(2,3,1)

bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 5=no')
# plt.xlabel('sex')
# plt.title('Gender')
plt.xticks(fontsize=7 , rotation=45)
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se6-sex.png',format='png', dpi=600)


################################################################
######################      AGE         ########################
################################################################

se6_age=df[['SOC4B','SOC4A','AGE7']]

se6_age.drop(se6_age.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se6_age.drop(se6_age.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_age.drop(se6_age.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se6_age.drop(se6_age.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_age.drop(se6_age.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se6_age.drop(se6_age.loc[df['AGE7']== '(88) Removed for disclosure risk'].index, inplace=True)

se6_age['SOC4B']=se6_age['SOC4B'].str[1:]
se6_age['SOC4B'] = se6_age['SOC4B'].str.split(')').str[0].astype(int)
se6_age['SOC4A']=se6_age['SOC4A'].str[1:]
se6_age['SOC4A'] = se6_age['SOC4A'].str.split(')').str[0].astype(int)

ticks = se6_age['AGE7'].sort_values().unique();
cols = se6_age['AGE7'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se6_age['AGE7'] == cols[i]
    data_b.append(se6_age[mask]['SOC4B'])
    data_a.append(se6_age[mask]['SOC4A'])

plt.subplot(2,3,2)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_a)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_b)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 5=no')
# plt.xlabel('Age')
# plt.title('Age')
plt.xticks(fontsize=7,rotation=45)
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se6-age.png',format='png', dpi=600)


################################################################
######################    INCOME        ########################
################################################################


se6_inc=df[['SOC4B','SOC4A','HHINCOME']]

# se6_inc['HHINCOME'].unique()

se6_inc.drop(se6_inc.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se6_inc.drop(se6_inc.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_inc.drop(se6_inc.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se6_inc.drop(se6_inc.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_inc.drop(se6_inc.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se6_inc.drop(se6_inc.loc[df['HHINCOME']== 'REFUSED'].index, inplace=True)
se6_inc.drop(se6_inc.loc[df['HHINCOME']== 'SKIPPED ON WEB'].index, inplace=True)
se6_inc.drop(se6_inc.loc[df['HHINCOME']== "DON'T KNOW"].index, inplace=True)
df['HHINCOME'] = df['HHINCOME'].replace(['Under $10,000'],'(1) $<10K')
df['HHINCOME'] = df['HHINCOME'].replace(['$10,000 to under $20,000'],'(2) 10K<$<20K')
df['HHINCOME'] = df['HHINCOME'].replace(['$20,000 to under $30,000'],'(3) 20K<$<30K')
df['HHINCOME'] = df['HHINCOME'].replace(['$30,000 to under $40,000'],'(4) 30K<$<40K')
df['HHINCOME'] = df['HHINCOME'].replace(['$40,000 to under $50,000'],'(5) 40K<$<50K')
df['HHINCOME'] = df['HHINCOME'].replace(['$50,000 to under $75,000'],'(6) 50K<$<75K')
df['HHINCOME'] = df['HHINCOME'].replace(['$75,000 to under $100,000'],'(7) 75K<$<100K')
df['HHINCOME'] = df['HHINCOME'].replace(['$100,000 to under $150,000'],'(8) 100K<$<150K')
df['HHINCOME'] = df['HHINCOME'].replace(['$150,000 or more'],'(9) $>150K')



se6_inc['SOC4B']=se6_inc['SOC4B'].str[1:]
se6_inc['SOC4B'] = se6_inc['SOC4B'].str.split(')').str[0].astype(int)
se6_inc['SOC4A']=se6_inc['SOC4A'].str[1:]
se6_inc['SOC4A'] = se6_inc['SOC4A'].str.split(')').str[0].astype(int)

ticks = se6_inc['HHINCOME'].sort_values().unique()
cols = se6_inc['HHINCOME'].unique()
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se6_inc['HHINCOME'] == cols[i]
    data_b.append(se6_inc[mask]['SOC4B'])
    data_a.append(se6_inc[mask]['SOC4A'])

plt.subplot(2,3,3)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 5=no')
# plt.xlabel('inc')
plt.xticks(fontsize=7,rotation=45)
# plt.title('Income')


plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se6-inc.png',format='png', dpi=600)


################################################################
######################    EDUCATION     ########################
################################################################

se6_edu=df[['SOC4B','SOC4A','EDUCATION']]

se6_edu['EDUCATION'].unique()


se6_edu.drop(se6_edu.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se6_edu.drop(se6_edu.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_edu.drop(se6_edu.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se6_edu.drop(se6_edu.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_edu.drop(se6_edu.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se6_edu.drop(se6_edu.loc[df['EDUCATION']== '(99) REFUSED'].index, inplace=True)
se6_edu.drop(se6_edu.loc[df['EDUCATION']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_edu.drop(se6_edu.loc[df['EDUCATION']== '(77) Not sure'].index, inplace=True)
df['EDUCATION'] = df['EDUCATION'].replace(['(2) HIGH SCHOOL GRADUATE - high school DIPLOMA or the equivalent (GED)'],'(2) HIGH SCHOOL GRADUATE')


se6_edu['SOC4B']=se6_edu['SOC4B'].str[1:]
se6_edu['SOC4B'] = se6_edu['SOC4B'].str.split(')').str[0].astype(int)
se6_edu['SOC4A']=se6_edu['SOC4A'].str[1:]
se6_edu['SOC4A'] = se6_edu['SOC4A'].str.split(')').str[0].astype(int)

ticks = se6_edu['EDUCATION'].sort_values().unique();
cols = se6_edu['EDUCATION'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se6_edu['EDUCATION'] == cols[i]
    data_b.append(se6_edu[mask]['SOC4B'])
    data_a.append(se6_edu[mask]['SOC4A'])

plt.subplot(2,3,4)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 5=no')
# plt.xlabel('edu')
plt.xticks(fontsize=7 , rotation=45)
# plt.title('Education')

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se6-edu.png',format='png', dpi=600)




################################################################
######################        RACE      ########################
################################################################

se6_rac=df[['SOC4B','SOC4A','RACETH']]

se6_rac['RACETH'].unique()


se6_rac.drop(se6_rac.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se6_rac.drop(se6_rac.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_rac.drop(se6_rac.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se6_rac.drop(se6_rac.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_rac.drop(se6_rac.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se6_rac.drop(se6_rac.loc[df['RACETH']== '(99) REFUSED'].index, inplace=True)
se6_rac.drop(se6_rac.loc[df['RACETH']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_rac.drop(se6_rac.loc[df['RACETH']== "(77) DON'T KNOW"].index, inplace=True)

se6_rac['SOC4B']=se6_rac['SOC4B'].str[1:]
se6_rac['SOC4B'] = se6_rac['SOC4B'].str.split(')').str[0].astype(int)
se6_rac['SOC4A']=se6_rac['SOC4A'].str[1:]
se6_rac['SOC4A'] = se6_rac['SOC4A'].str.split(')').str[0].astype(int)

ticks = se6_rac['RACETH'].sort_values().unique();
cols = se6_rac['RACETH'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se6_rac['RACETH'] == cols[i]
    data_b.append(se6_rac[mask]['SOC4B'])
    data_a.append(se6_rac[mask]['SOC4A'])

plt.subplot(2,3,5)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 5=no')
# plt.xlabel('rac')
plt.xticks(fontsize=7 , rotation=45)
# plt.title('Race')

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se6-rac.png',format='png', dpi=600)


################################################################
######################        SOC1      ########################
################################################################

se6_soc=df[['SOC4B','SOC4A','SOC1']]

se6_soc['SOC1'].unique()


se6_soc.drop(se6_soc.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se6_soc.drop(se6_soc.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_soc.drop(se6_soc.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se6_soc.drop(se6_soc.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_soc.drop(se6_soc.loc[df['SOC1']== '(98) SKIPPED ON WEB'].index, inplace=True)
se6_soc.drop(se6_soc.loc[df['SOC1']== "(77) DON'T KNOW"].index, inplace=True)

se6_soc['SOC4B']=se6_soc['SOC4B'].str[1:]
se6_soc['SOC4B'] = se6_soc['SOC4B'].str.split(')').str[0].astype(int)
se6_soc['SOC4A']=se6_soc['SOC4A'].str[1:]
se6_soc['SOC4A'] = se6_soc['SOC4A'].str.split(')').str[0].astype(int)

ticks = se6_soc['SOC1'].sort_values().unique();
cols = se6_soc['SOC1'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se6_soc['SOC1'] == cols[i]
    data_b.append(se6_soc[mask]['SOC4B'])
    data_a.append(se6_soc[mask]['SOC4A'])

plt.subplot(2,3,6)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 5=no')
# plt.xlabel('soc')
plt.xticks(fontsize=7 , rotation=45)
# plt.title('Trust people in your neighborhood')

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se6-soc.png',format='png', dpi=600)

fig.suptitle('Changes in volunteer activities due to Covid-19 pandemic')

fig.savefig('C:\python\SE6.png',format='png', dpi=600)
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_16096\2253350808.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se6_sex.drop(se6_sex.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_16096\2253350808.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se6_sex.drop(se6_sex.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_16096\2253350808.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
import numpy as np

################################################################
######################    GENDER        ########################
################################################################

se2_sex=df[['SOC4B','SOC4A','GENDER']]

import textwrap
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=0)

se2_sex.drop(se2_sex.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se2_sex.drop(se2_sex.loc[df['GENDER']== '(98) SKIPPED ON WEB'].index, inplace=True)

se2_sex['SOC4B']=se2_sex['SOC4B'].str[1:]
se2_sex['SOC4B'] = se2_sex['SOC4B'].str.split(')').str[0].astype(int)
se2_sex['SOC4A']=se2_sex['SOC4A'].str[1:]
se2_sex['SOC4A'] = se2_sex['SOC4A'].str.split(')').str[0].astype(int)

x1 = se2_sex['GENDER'].sort_values().unique();
ticks = [ '\n'.join(textwrap.wrap(l, 10)) for l in x1]
cols = se2_sex['GENDER'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_sex['GENDER'] == cols[i]
    data_b.append(se2_sex[mask]['SOC4B'])
    data_a.append(se2_sex[mask]['SOC4A'])

fig, axs = plt.subplots(3, 2, constrained_layout=True,figsize=(20,20))
# fig = plt.figure(figsize=(15, 8))

plt.sca(axs[0,0])
plt.title('(A) Gender',fontsize=22)
plt.yticks(fontsize=20)
plt.sca(axs[0,1])
plt.title('(B) Age',fontsize=22)
plt.yticks(fontsize=20)
plt.sca(axs[1,0])
plt.title('(C) Income',fontsize=22)
plt.yticks(fontsize=20)
plt.sca(axs[1,1])
plt.title('(D) Education',fontsize=22)
plt.yticks(fontsize=20)
plt.sca(axs[2,0])
plt.title('(E) Race',fontsize=22)
plt.yticks(fontsize=20)
plt.sca(axs[2,1])
plt.title('(F) Trust People in Neighborhood',fontsize=22)
plt.yticks(fontsize=20)





plt.suptitle('Changes in Volunteer Activites', fontsize=24)



plt.subplot(3,2,1)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 2=no',fontsize=20)
# plt.xlabel('sex')
# plt.title('Gender')
# axs[0].xlabel('Gender')
plt.xticks(fontsize=20)
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se2-sex.png',format='png', dpi=600)


################################################################
######################      AGE         ########################
################################################################

se2_age=df[['SOC4B','SOC4A','AGE7']]

se2_age.drop(se2_age.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_age.drop(se2_age.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se2_age.drop(se2_age.loc[df['AGE7']== '(88) Removed for disclosure risk'].index, inplace=True)
# df['AGE7'] = df['AGE7'].replace(['Under $10,000'],'1-$<10K')


se2_age['SOC4B']=se2_age['SOC4B'].str[1:]
se2_age['SOC4B'] = se2_age['SOC4B'].str.split(')').str[0].astype(int)
se2_age['SOC4A']=se2_age['SOC4A'].str[1:]
se2_age['SOC4A'] = se2_age['SOC4A'].str.split(')').str[0].astype(int)

x2 = se2_age['AGE7'].sort_values().unique();
ticks = [ '\n'.join(textwrap.wrap(l, 10)) for l in x2]
cols = se2_age['AGE7'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_age['AGE7'] == cols[i]
    data_b.append(se2_age[mask]['SOC4B'])
    data_a.append(se2_age[mask]['SOC4A'])

plt.subplot(3,2,2)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_a)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_b)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 2=no',fontsize=20)
# plt.xlabel('Age')
# plt.title('Age')
plt.xticks(fontsize=20,rotation=45)
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se2-age.png',format='png', dpi=600)


################################################################
######################    INCOME        ########################
################################################################


se2_inc=df[['SOC4B','SOC4A','HHINCOME']]

# se2_inc['HHINCOME'].unique()

se2_inc.drop(se2_inc.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['HHINCOME']== 'REFUSED'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['HHINCOME']== 'SKIPPED ON WEB'].index, inplace=True)
se2_inc.drop(se2_inc.loc[df['HHINCOME']== "DON'T KNOW"].index, inplace=True)
df['HHINCOME'] = df['HHINCOME'].replace(['Under $10,000'],'(1) $<10K')
df['HHINCOME'] = df['HHINCOME'].replace(['$10,000 to under $20,000'],'(2) 10K<$<20K')
df['HHINCOME'] = df['HHINCOME'].replace(['$20,000 to under $30,000'],'(3) 20K<$<30K')
df['HHINCOME'] = df['HHINCOME'].replace(['$30,000 to under $40,000'],'(4) 30K<$<40K')
df['HHINCOME'] = df['HHINCOME'].replace(['$40,000 to under $50,000'],'(5) 40K<$<50K')
df['HHINCOME'] = df['HHINCOME'].replace(['$50,000 to under $75,000'],'(6) 50K<$<75K')
df['HHINCOME'] = df['HHINCOME'].replace(['$75,000 to under $100,000'],'(7) 75K<$<100K')
df['HHINCOME'] = df['HHINCOME'].replace(['$100,000 to under $150,000'],'(8) 100K<$<150K')
df['HHINCOME'] = df['HHINCOME'].replace(['$150,000 or more'],'(9) $>150K')



se2_inc['SOC4B']=se2_inc['SOC4B'].str[1:]
se2_inc['SOC4B'] = se2_inc['SOC4B'].str.split(')').str[0].astype(int)
se2_inc['SOC4A']=se2_inc['SOC4A'].str[1:]
se2_inc['SOC4A'] = se2_inc['SOC4A'].str.split(')').str[0].astype(int)

x3 = se2_inc['HHINCOME'].sort_values().unique()
ticks = [ '\n'.join(textwrap.wrap(l, 10)) for l in x3]
cols = se2_inc['HHINCOME'].unique()
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_inc['HHINCOME'] == cols[i]
    data_b.append(se2_inc[mask]['SOC4B'])
    data_a.append(se2_inc[mask]['SOC4A'])

plt.subplot(3,2,3)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 2=no',fontsize=20)
# plt.xlabel('inc')
plt.xticks(fontsize=16,rotation=45)
# plt.title('Income')


plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se2-inc.png',format='png', dpi=600)


################################################################
######################    EDUCATION     ########################
################################################################

se2_edu=df[['SOC4B','SOC4A','EDUCATION']]

se2_edu['EDUCATION'].unique()


se2_edu.drop(se2_edu.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(99) REFUSED'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_edu.drop(se2_edu.loc[df['EDUCATION']== '(77) Not sure'].index, inplace=True)
df['EDUCATION'] = df['EDUCATION'].replace(['(2) HIGH SCHOOL GRADUATE - high school DIPLOMA or the equivalent (GED)'],'(2) HIGH SCHOOL GRADUATE')


se2_edu['SOC4B']=se2_edu['SOC4B'].str[1:]
se2_edu['SOC4B'] = se2_edu['SOC4B'].str.split(')').str[0].astype(int)
se2_edu['SOC4A']=se2_edu['SOC4A'].str[1:]
se2_edu['SOC4A'] = se2_edu['SOC4A'].str.split(')').str[0].astype(int)

# ticks = se2_edu['EDUCATION'].sort_values().unique();
x4 = se2_edu['EDUCATION'].sort_values().unique();
ticks = [ '\n'.join(textwrap.wrap(l, 10)) for l in x4]

cols = se2_edu['EDUCATION'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_edu['EDUCATION'] == cols[i]
    data_b.append(se2_edu[mask]['SOC4B'])
    data_a.append(se2_edu[mask]['SOC4A'])

plt.subplot(3,2,4)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 2=no',fontsize=20)
# plt.xlabel('edu')
plt.xticks(fontsize=16,rotation=45)
# plt.title('Education')

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
# plt.tight_layout()
# plt.savefig('C:\python\se2-edu.png',format='png', dpi=600)




################################################################
######################        RACE      ########################
################################################################

se2_rac=df[['SOC4B','SOC4A','RACETH']]

se2_rac['RACETH'].unique()


se2_rac.drop(se2_rac.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['SOC4A']== '(99) REFUSED'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['RACETH']== '(99) REFUSED'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['RACETH']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_rac.drop(se2_rac.loc[df['RACETH']== "(77) DON'T KNOW"].index, inplace=True)

se2_rac['SOC4B']=se2_rac['SOC4B'].str[1:]
se2_rac['SOC4B'] = se2_rac['SOC4B'].str.split(')').str[0].astype(int)
se2_rac['SOC4A']=se2_rac['SOC4A'].str[1:]
se2_rac['SOC4A'] = se2_rac['SOC4A'].str.split(')').str[0].astype(int)

x5 = se2_rac['RACETH'].sort_values().unique();
ticks = [ '\n'.join(textwrap.wrap(l, 10)) for l in x5]
cols = se2_rac['RACETH'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_rac['RACETH'] == cols[i]
    data_b.append(se2_rac[mask]['SOC4B'])
    data_a.append(se2_rac[mask]['SOC4A'])

plt.subplot(3,2,5)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 2=no',fontsize=20)
# plt.xlabel('rac')
plt.xticks(fontsize=20)
# plt.title('Race')

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# plt.savefig('C:\python\se2-rac.png',format='png', dpi=600)


################################################################
######################        SOC1      ########################
################################################################

se2_soc=df[['SOC4B','SOC4A','SOC1']]

se2_soc['SOC1'].unique()


se2_soc.drop(se2_soc.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC4A']== '(77) Not sure'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC4A']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC1']== '(98) SKIPPED ON WEB'].index, inplace=True)
se2_soc.drop(se2_soc.loc[df['SOC1']== "(77) DON'T KNOW"].index, inplace=True)

se2_soc['SOC4B']=se2_soc['SOC4B'].str[1:]
se2_soc['SOC4B'] = se2_soc['SOC4B'].str.split(')').str[0].astype(int)
se2_soc['SOC4A']=se2_soc['SOC4A'].str[1:]
se2_soc['SOC4A'] = se2_soc['SOC4A'].str.split(')').str[0].astype(int)

x6 = se2_soc['SOC1'].sort_values().unique();
ticks = [ '\n'.join(textwrap.wrap(l, 10)) for l in x6]
cols = se2_soc['SOC1'].unique();
mask=[]
data_b=[]
data_a=[]

for i in range(len(ticks)):
    mask = se2_soc['SOC1'] == cols[i]
    data_b.append(se2_soc[mask]['SOC4B'])
    data_a.append(se2_soc[mask]['SOC4A'])


plt.subplot(3,2,6)
bpl = plt.boxplot(data_b,
                  positions=np.array(range(len(data_b)))*2.0-0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})

bpr = plt.boxplot(data_a,
                  positions=np.array(range(len(data_a)))*2.0+0.4,
                  sym='',
                  widths=0.6,
                  showmeans=True,
                  meanprops={"marker":"o",
                             "markerfacecolor":"white",
                             "markeredgecolor":"black",
                             "markersize":"2"})


def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

set_box_color(bpl, '#2C7BB6') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#D7191C')

plt.plot([], c='#2C7BB6', label='Before Pandemic')
plt.plot([], c='#D7191C', label='Last Month')
plt.legend()
plt.ylabel('1=yes 2=no',fontsize=20 )
# plt.xlabel('soc')
plt.xticks(fontsize=20)
# plt.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
#                alpha=0.5)
# plt.title('Trust people in your neighborhood')


# wrap_labels(plt, 10)


plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 3)
plt.tight_layout()
# axs.tick_params(axis="y", labelsize=20)
# plt.savefig('C:\python\se2-soc.png',format='png', dpi=600)

# fig.suptitle('Changes in Social Relationships due to Covid-19 pandemic', fontsize=24)

fig.savefig('C:\python\SE06.jpeg',format='jpeg', dpi=300)
# Out:
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21544\4283892203.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['SOC4B']== '(77) Not sure'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21544\4283892203.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   se2_sex.drop(se2_sex.loc[df['SOC4B']== '(98) SKIPPED ON WEB'].index, inplace=True)
# C:\Users\meisamasgri\AppData\Local\Temp\ipykernel_21544\4283892203.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
