# %%
#IMPORTING DATASET(.CSV) INTO PANDAS DATAFRAME
import pandas as pd
df = pd.read_csv('02_May_12_covid_impact_survey.csv',
                       sep=',',
                       index_col=False,
                       dtype='unicode')
df
# Out:
#      Unnamed: 0       SU_ID     P_PANEL NATIONAL_WEIGHT REGION_WEIGHT  \
# 0             1  0020000024         ABS             NaN  0.4062974839
# 1             2  0020001653         ABS             NaN  0.3187468867
# 2             3  0020001908         ABS             NaN  0.5459146697
# 3             4  0020002623         ABS             NaN  0.9353794308
# 4             5  0020007751         ABS             NaN  1.4608136632
# ...         ...         ...         ...             ...           ...
# 8969       8970  0040008564  Amerispeak        0.138111           NaN
# 8970       8971  0040008565  Amerispeak      1.34786936           NaN
# 8971       8972  0040008566  Amerispeak    0.7866569101           NaN
# 8972       8973  0040008567  Amerispeak    0.5721682663           NaN
# 8973       8974  0040008569  Amerispeak    0.8579810309  0.5002794999
#
#      NATIONAL_WEIGHT_POP REGION_WEIGHT_POP NAT_WGT_COMB_POP REG_WGT_COMB_POP  \
# ...

# %%
df['HHINCOME'].value_counts()
# Out:
# 50,000 to under $75,000      1628
# 100,000 to under $150,000    1401
# 75,000 to under $100,000     1294
# 150,000 or more              1091
# 20,000 to under $30,000       831
# 30,000 to under $40,000       782
# 40,000 to under $50,000       704
# 10,000 to under $20,000       606
# nder $10,000                  414
# KIPPED ON WEB                 130
# EFUSED                         77
# ON'T KNOW                      16
# Name: HHINCOME, dtype: int64

# %%
#CONVERTING CATEGORICAL TO NUMERICAL DATA USING DATASET VALUES
del df['Unnamed: 0']
del df['P_PANEL']
del df['P_GEO']

# df['COLUMN_A']=df['COLUMN_A'].str[1:]; df['COLUMN_A'] = df['COLUMN_A'].str.split(')').str[0].astype(int)
# df['SU_ID']=df['SU_ID'].str[1:]; df['SU_ID'] = df['SU_ID'].str.split(')').str[0].astype(int)
# df['P_PANEL']=df['P_PANEL'].str[1:]; df['P_PANEL'] = df['P_PANEL'].str.split(')').str[0].astype(int)
# df['NATIONAL_WEIGHT']=df['NATIONAL_WEIGHT'].str[1:]; df['NATIONAL_WEIGHT'] = df['NATIONAL_WEIGHT'].str.split(')').str[0].astype(int)
# df['REGION_WEIGHT']=df['REGION_WEIGHT'].str[1:]; df['REGION_WEIGHT'] = df['REGION_WEIGHT'].str.split(')').str[0].astype(int)
# df['NATIONAL_WEIGHT_POP']=df['NATIONAL_WEIGHT_POP'].str[1:]; df['NATIONAL_WEIGHT_POP'] = df['NATIONAL_WEIGHT_POP'].str.split(')').str[0].astype(int)
# df['REGION_WEIGHT_POP']=df['REGION_WEIGHT_POP'].str[1:]; df['REGION_WEIGHT_POP'] = df['REGION_WEIGHT_POP'].str.split(')').str[0].astype(int)
# df['NAT_WGT_COMB_POP']=df['NAT_WGT_COMB_POP'].str[1:]; df['NAT_WGT_COMB_POP'] = df['NAT_WGT_COMB_POP'].str.split(')').str[0].astype(int)
# df['REG_WGT_COMB_POP']=df['REG_WGT_COMB_POP'].str[1:]; df['REG_WGT_COMB_POP'] = df['REG_WGT_COMB_POP'].str.split(')').str[0].astype(int)
# df['P_GEO']=df['P_GEO'].str[1:]; df['P_GEO'] = df['P_GEO'].str.split(')').str[0].astype(int)
df['SOC1']=df['SOC1'].str[1:]; df['SOC1'] = df['SOC1'].str.split(')').str[0].astype(int)
df['SOC2A']=df['SOC2A'].str[1:]; df['SOC2A'] = df['SOC2A'].str.split(')').str[0].astype(int)
df['SOC2B']=df['SOC2B'].str[1:]; df['SOC2B'] = df['SOC2B'].str.split(')').str[0].astype(int)
df['SOC3A']=df['SOC3A'].str[1:]; df['SOC3A'] = df['SOC3A'].str.split(')').str[0].astype(int)
df['SOC3B']=df['SOC3B'].str[1:]; df['SOC3B'] = df['SOC3B'].str.split(')').str[0].astype(int)
df['SOC4A']=df['SOC4A'].str[1:]; df['SOC4A'] = df['SOC4A'].str.split(')').str[0].astype(int)
df['SOC4B']=df['SOC4B'].str[1:]; df['SOC4B'] = df['SOC4B'].str.split(')').str[0].astype(int)
df['PHYS8']=df['PHYS8'].str[1:]; df['PHYS8'] = df['PHYS8'].str.split(')').str[0].astype(int)
df['PHYS1A']=df['PHYS1A'].str[1:]; df['PHYS1A'] = df['PHYS1A'].str.split(')').str[0].astype(int)
df['PHYS1B']=df['PHYS1B'].str[1:]; df['PHYS1B'] = df['PHYS1B'].str.split(')').str[0].astype(int)
df['PHYS1C']=df['PHYS1C'].str[1:]; df['PHYS1C'] = df['PHYS1C'].str.split(')').str[0].astype(int)
df['PHYS1D']=df['PHYS1D'].str[1:]; df['PHYS1D'] = df['PHYS1D'].str.split(')').str[0].astype(int)
df['PHYS1E']=df['PHYS1E'].str[1:]; df['PHYS1E'] = df['PHYS1E'].str.split(')').str[0].astype(int)
df['PHYS1F']=df['PHYS1F'].str[1:]; df['PHYS1F'] = df['PHYS1F'].str.split(')').str[0].astype(int)
df['PHYS1G']=df['PHYS1G'].str[1:]; df['PHYS1G'] = df['PHYS1G'].str.split(')').str[0].astype(int)
df['PHYS1H']=df['PHYS1H'].str[1:]; df['PHYS1H'] = df['PHYS1H'].str.split(')').str[0].astype(int)
df['PHYS1I']=df['PHYS1I'].str[1:]; df['PHYS1I'] = df['PHYS1I'].str.split(')').str[0].astype(int)
df['PHYS1J']=df['PHYS1J'].str[1:]; df['PHYS1J'] = df['PHYS1J'].str.split(')').str[0].astype(int)
df['PHYS1K']=df['PHYS1K'].str[1:]; df['PHYS1K'] = df['PHYS1K'].str.split(')').str[0].astype(int)
df['PHYS1L']=df['PHYS1L'].str[1:]; df['PHYS1L'] = df['PHYS1L'].str.split(')').str[0].astype(int)
df['PHYS1M']=df['PHYS1M'].str[1:]; df['PHYS1M'] = df['PHYS1M'].str.split(')').str[0].astype(int)
df['PHYS1N']=df['PHYS1N'].str[1:]; df['PHYS1N'] = df['PHYS1N'].str.split(')').str[0].astype(int)
df['PHYS1O']=df['PHYS1O'].str[1:]; df['PHYS1O'] = df['PHYS1O'].str.split(')').str[0].astype(int)
df['PHYS1P']=df['PHYS1P'].str[1:]; df['PHYS1P'] = df['PHYS1P'].str.split(')').str[0].astype(int)
df['PHYS1Q']=df['PHYS1Q'].str[1:]; df['PHYS1Q'] = df['PHYS1Q'].str.split(')').str[0].astype(int)
df['SOC5A']=df['SOC5A'].str[1:]; df['SOC5A'] = df['SOC5A'].str.split(')').str[0].astype(int)
df['SOC5B']=df['SOC5B'].str[1:]; df['SOC5B'] = df['SOC5B'].str.split(')').str[0].astype(int)
df['SOC5C']=df['SOC5C'].str[1:]; df['SOC5C'] = df['SOC5C'].str.split(')').str[0].astype(int)
df['SOC5D']=df['SOC5D'].str[1:]; df['SOC5D'] = df['SOC5D'].str.split(')').str[0].astype(int)
df['SOC5E']=df['SOC5E'].str[1:]; df['SOC5E'] = df['SOC5E'].str.split(')').str[0].astype(int)
df['PHYS2_1']=df['PHYS2_1'].str[1:]; df['PHYS2_1'] = df['PHYS2_1'].str.split(')').str[0].astype(int)
df['PHYS2_2']=df['PHYS2_2'].str[1:]; df['PHYS2_2'] = df['PHYS2_2'].str.split(')').str[0].astype(int)
df['PHYS2_3']=df['PHYS2_3'].str[1:]; df['PHYS2_3'] = df['PHYS2_3'].str.split(')').str[0].astype(int)
df['PHYS2_4']=df['PHYS2_4'].str[1:]; df['PHYS2_4'] = df['PHYS2_4'].str.split(')').str[0].astype(int)
df['PHYS2_5']=df['PHYS2_5'].str[1:]; df['PHYS2_5'] = df['PHYS2_5'].str.split(')').str[0].astype(int)
df['PHYS2_6']=df['PHYS2_6'].str[1:]; df['PHYS2_6'] = df['PHYS2_6'].str.split(')').str[0].astype(int)
df['PHYS2_7']=df['PHYS2_7'].str[1:]; df['PHYS2_7'] = df['PHYS2_7'].str.split(')').str[0].astype(int)
df['PHYS2_8']=df['PHYS2_8'].str[1:]; df['PHYS2_8'] = df['PHYS2_8'].str.split(')').str[0].astype(int)
df['PHYS2_9']=df['PHYS2_9'].str[1:]; df['PHYS2_9'] = df['PHYS2_9'].str.split(')').str[0].astype(int)
df['PHYS2_10']=df['PHYS2_10'].str[1:]; df['PHYS2_10'] = df['PHYS2_10'].str.split(')').str[0].astype(int)
df['PHYS2_11']=df['PHYS2_11'].str[1:]; df['PHYS2_11'] = df['PHYS2_11'].str.split(')').str[0].astype(int)
df['PHYS2_12']=df['PHYS2_12'].str[1:]; df['PHYS2_12'] = df['PHYS2_12'].str.split(')').str[0].astype(int)
df['PHYS2_13']=df['PHYS2_13'].str[1:]; df['PHYS2_13'] = df['PHYS2_13'].str.split(')').str[0].astype(int)
df['PHYS2_14']=df['PHYS2_14'].str[1:]; df['PHYS2_14'] = df['PHYS2_14'].str.split(')').str[0].astype(int)
df['PHYS2_15']=df['PHYS2_15'].str[1:]; df['PHYS2_15'] = df['PHYS2_15'].str.split(')').str[0].astype(int)
df['PHYS2_16']=df['PHYS2_16'].str[1:]; df['PHYS2_16'] = df['PHYS2_16'].str.split(')').str[0].astype(int)
df['PHYS2_17']=df['PHYS2_17'].str[1:]; df['PHYS2_17'] = df['PHYS2_17'].str.split(')').str[0].astype(int)
df['PHYS2_18']=df['PHYS2_18'].str[1:]; df['PHYS2_18'] = df['PHYS2_18'].str.split(')').str[0].astype(int)
df['PHYS2_19']=df['PHYS2_19'].str[1:]; df['PHYS2_19'] = df['PHYS2_19'].str.split(')').str[0].astype(int)
df['PHYS2_DK']=df['PHYS2_DK'].str[1:]; df['PHYS2_DK'] = df['PHYS2_DK'].str.split(')').str[0].astype(int)
df['PHYS2_SKP']=df['PHYS2_SKP'].str[1:]; df['PHYS2_SKP'] = df['PHYS2_SKP'].str.split(')').str[0].astype(int)
df['PHYS2_REF']=df['PHYS2_REF'].str[1:]; df['PHYS2_REF'] = df['PHYS2_REF'].str.split(')').str[0].astype(int)
df['PHYS10A']=df['PHYS10A'].str[1:]; df['PHYS10A'] = df['PHYS10A'].str.split(')').str[0].astype(int)
df['PHYS10B']=df['PHYS10B'].str[1:]; df['PHYS10B'] = df['PHYS10B'].str.split(')').str[0].astype(int)
df['PHYS10C']=df['PHYS10C'].str[1:]; df['PHYS10C'] = df['PHYS10C'].str.split(')').str[0].astype(int)
df['PHYS10D']=df['PHYS10D'].str[1:]; df['PHYS10D'] = df['PHYS10D'].str.split(')').str[0].astype(int)
df['PHYS10E']=df['PHYS10E'].str[1:]; df['PHYS10E'] = df['PHYS10E'].str.split(')').str[0].astype(int)
df['ECON8A']=df['ECON8A'].str[1:]; df['ECON8A'] = df['ECON8A'].str.split(')').str[0].astype(int)
df['ECON8B']=df['ECON8B'].str[1:]; df['ECON8B'] = df['ECON8B'].str.split(')').str[0].astype(int)
df['ECON8C']=df['ECON8C'].str[1:]; df['ECON8C'] = df['ECON8C'].str.split(')').str[0].astype(int)
df['ECON8D']=df['ECON8D'].str[1:]; df['ECON8D'] = df['ECON8D'].str.split(')').str[0].astype(int)
df['ECON8E']=df['ECON8E'].str[1:]; df['ECON8E'] = df['ECON8E'].str.split(')').str[0].astype(int)
df['ECON8F']=df['ECON8F'].str[1:]; df['ECON8F'] = df['ECON8F'].str.split(')').str[0].astype(int)
df['ECON8G']=df['ECON8G'].str[1:]; df['ECON8G'] = df['ECON8G'].str.split(')').str[0].astype(int)
df['ECON8H']=df['ECON8H'].str[1:]; df['ECON8H'] = df['ECON8H'].str.split(')').str[0].astype(int)
df['ECON8I']=df['ECON8I'].str[1:]; df['ECON8I'] = df['ECON8I'].str.split(')').str[0].astype(int)
df['ECON8J']=df['ECON8J'].str[1:]; df['ECON8J'] = df['ECON8J'].str.split(')').str[0].astype(int)
df['ECON8K']=df['ECON8K'].str[1:]; df['ECON8K'] = df['ECON8K'].str.split(')').str[0].astype(int)
df['ECON8L']=df['ECON8L'].str[1:]; df['ECON8L'] = df['ECON8L'].str.split(')').str[0].astype(int)
df['ECON8M']=df['ECON8M'].str[1:]; df['ECON8M'] = df['ECON8M'].str.split(')').str[0].astype(int)
df['ECON8N']=df['ECON8N'].str[1:]; df['ECON8N'] = df['ECON8N'].str.split(')').str[0].astype(int)
df['ECON8O']=df['ECON8O'].str[1:]; df['ECON8O'] = df['ECON8O'].str.split(')').str[0].astype(int)
df['ECON8P']=df['ECON8P'].str[1:]; df['ECON8P'] = df['ECON8P'].str.split(')').str[0].astype(int)
df['ECON8Q']=df['ECON8Q'].str[1:]; df['ECON8Q'] = df['ECON8Q'].str.split(')').str[0].astype(int)
df['ECON8R']=df['ECON8R'].str[1:]; df['ECON8R'] = df['ECON8R'].str.split(')').str[0].astype(int)
df['ECON8S']=df['ECON8S'].str[1:]; df['ECON8S'] = df['ECON8S'].str.split(')').str[0].astype(int)
df['ECON7_1']=df['ECON7_1'].str[1:]; df['ECON7_1'] = df['ECON7_1'].str.split(')').str[0].astype(int)
df['ECON7_2']=df['ECON7_2'].str[1:]; df['ECON7_2'] = df['ECON7_2'].str.split(')').str[0].astype(int)
df['ECON7_3']=df['ECON7_3'].str[1:]; df['ECON7_3'] = df['ECON7_3'].str.split(')').str[0].astype(int)
df['ECON7_4']=df['ECON7_4'].str[1:]; df['ECON7_4'] = df['ECON7_4'].str.split(')').str[0].astype(int)
df['ECON7_5']=df['ECON7_5'].str[1:]; df['ECON7_5'] = df['ECON7_5'].str.split(')').str[0].astype(int)
df['ECON7_6']=df['ECON7_6'].str[1:]; df['ECON7_6'] = df['ECON7_6'].str.split(')').str[0].astype(int)
df['ECON7_7']=df['ECON7_7'].str[1:]; df['ECON7_7'] = df['ECON7_7'].str.split(')').str[0].astype(int)
df['ECON7_8']=df['ECON7_8'].str[1:]; df['ECON7_8'] = df['ECON7_8'].str.split(')').str[0].astype(int)
df['ECON7_DK']=df['ECON7_DK'].str[1:]; df['ECON7_DK'] = df['ECON7_DK'].str.split(')').str[0].astype(int)
df['ECON7_SKP']=df['ECON7_SKP'].str[1:]; df['ECON7_SKP'] = df['ECON7_SKP'].str.split(')').str[0].astype(int)
df['ECON7_REF']=df['ECON7_REF'].str[1:]; df['ECON7_REF'] = df['ECON7_REF'].str.split(')').str[0].astype(int)
df['ECON1']=df['ECON1'].str[1:]; df['ECON1'] = df['ECON1'].str.split(')').str[0].astype(int)
# df['ECON2']=df['ECON2'].str[1:]; df['ECON2'] = df['ECON2'].str.split(')').str[0].astype(int)
# df['ECON4']=df['ECON4'].str[1:]; df['ECON4'] = df['ECON4'].str.split(')').str[0].astype(int)

# df['ECON3'].replace({'(998) SKIPPED ON WEB': '998'},
#                               inplace=True)
# df['ECON3']=df['ECON3'].str[1:]; df['ECON3'] = df['ECON3'].str.split(')').str[0].astype(int)

del df['ECON3']
del df['ECON4']
df['ECON4A']=df['ECON4A'].str[1:]; df['ECON4A'] = df['ECON4A'].str.split(')').str[0].astype(int)
df['ECON4B']=df['ECON4B'].str[1:]; df['ECON4B'] = df['ECON4B'].str.split(')').str[0].astype(int)
df['ECON6A']=df['ECON6A'].str[1:]; df['ECON6A'] = df['ECON6A'].str.split(')').str[0].astype(int)
df['ECON6B']=df['ECON6B'].str[1:]; df['ECON6B'] = df['ECON6B'].str.split(')').str[0].astype(int)
df['ECON6C']=df['ECON6C'].str[1:]; df['ECON6C'] = df['ECON6C'].str.split(')').str[0].astype(int)
df['ECON6D']=df['ECON6D'].str[1:]; df['ECON6D'] = df['ECON6D'].str.split(')').str[0].astype(int)
df['ECON6E']=df['ECON6E'].str[1:]; df['ECON6E'] = df['ECON6E'].str.split(')').str[0].astype(int)
df['ECON6F']=df['ECON6F'].str[1:]; df['ECON6F'] = df['ECON6F'].str.split(')').str[0].astype(int)
df['ECON6G']=df['ECON6G'].str[1:]; df['ECON6G'] = df['ECON6G'].str.split(')').str[0].astype(int)
df['ECON6H']=df['ECON6H'].str[1:]; df['ECON6H'] = df['ECON6H'].str.split(')').str[0].astype(int)
df['ECON6I']=df['ECON6I'].str[1:]; df['ECON6I'] = df['ECON6I'].str.split(')').str[0].astype(int)
df['ECON6J']=df['ECON6J'].str[1:]; df['ECON6J'] = df['ECON6J'].str.split(')').str[0].astype(int)
df['ECON6K']=df['ECON6K'].str[1:]; df['ECON6K'] = df['ECON6K'].str.split(')').str[0].astype(int)
df['ECON6L']=df['ECON6L'].str[1:]; df['ECON6L'] = df['ECON6L'].str.split(')').str[0].astype(int)
df['ECON5A_A']=df['ECON5A_A'].str[1:]; df['ECON5A_A'] = df['ECON5A_A'].str.split(')').str[0].astype(int)
df['ECON5A_B']=df['ECON5A_B'].str[1:]; df['ECON5A_B'] = df['ECON5A_B'].str.split(')').str[0].astype(int)
df['PHYS7_1']=df['PHYS7_1'].str[1:]; df['PHYS7_1'] = df['PHYS7_1'].str.split(')').str[0].astype(int)
df['PHYS7_2']=df['PHYS7_2'].str[1:]; df['PHYS7_2'] = df['PHYS7_2'].str.split(')').str[0].astype(int)
df['PHYS7_3']=df['PHYS7_3'].str[1:]; df['PHYS7_3'] = df['PHYS7_3'].str.split(')').str[0].astype(int)
df['PHYS7_4']=df['PHYS7_4'].str[1:]; df['PHYS7_4'] = df['PHYS7_4'].str.split(')').str[0].astype(int)
df['PHYS7_DK']=df['PHYS7_DK'].str[1:]; df['PHYS7_DK'] = df['PHYS7_DK'].str.split(')').str[0].astype(int)
df['PHYS7_SKP']=df['PHYS7_SKP'].str[1:]; df['PHYS7_SKP'] = df['PHYS7_SKP'].str.split(')').str[0].astype(int)
df['PHYS7_REF']=df['PHYS7_REF'].str[1:]; df['PHYS7_REF'] = df['PHYS7_REF'].str.split(')').str[0].astype(int)
df['PHYS11']=df['PHYS11'].str[1:]; df['PHYS11'] = df['PHYS11'].str.split(')').str[0].astype(int)
# df['PHYS11_TEMP']=df['PHYS11_TEMP'].str[1:]; df['PHYS11_TEMP'] = df['PHYS11_TEMP'].str.split(')').str[0].astype(int)
df['PHYS9A']=df['PHYS9A'].str[1:]; df['PHYS9A'] = df['PHYS9A'].str.split(')').str[0].astype(int)
df['PHYS9B']=df['PHYS9B'].str[1:]; df['PHYS9B'] = df['PHYS9B'].str.split(')').str[0].astype(int)
df['PHYS9C']=df['PHYS9C'].str[1:]; df['PHYS9C'] = df['PHYS9C'].str.split(')').str[0].astype(int)
df['PHYS9D']=df['PHYS9D'].str[1:]; df['PHYS9D'] = df['PHYS9D'].str.split(')').str[0].astype(int)
df['PHYS9E']=df['PHYS9E'].str[1:]; df['PHYS9E'] = df['PHYS9E'].str.split(')').str[0].astype(int)
df['PHYS9F']=df['PHYS9F'].str[1:]; df['PHYS9F'] = df['PHYS9F'].str.split(')').str[0].astype(int)
df['PHYS9G']=df['PHYS9G'].str[1:]; df['PHYS9G'] = df['PHYS9G'].str.split(')').str[0].astype(int)
df['PHYS9H']=df['PHYS9H'].str[1:]; df['PHYS9H'] = df['PHYS9H'].str.split(')').str[0].astype(int)
df['PHYS3A']=df['PHYS3A'].str[1:]; df['PHYS3A'] = df['PHYS3A'].str.split(')').str[0].astype(int)
df['PHYS3B']=df['PHYS3B'].str[1:]; df['PHYS3B'] = df['PHYS3B'].str.split(')').str[0].astype(int)
df['PHYS3C']=df['PHYS3C'].str[1:]; df['PHYS3C'] = df['PHYS3C'].str.split(')').str[0].astype(int)
df['PHYS3D']=df['PHYS3D'].str[1:]; df['PHYS3D'] = df['PHYS3D'].str.split(')').str[0].astype(int)
df['PHYS3E']=df['PHYS3E'].str[1:]; df['PHYS3E'] = df['PHYS3E'].str.split(')').str[0].astype(int)
df['PHYS3F']=df['PHYS3F'].str[1:]; df['PHYS3F'] = df['PHYS3F'].str.split(')').str[0].astype(int)
df['PHYS3G']=df['PHYS3G'].str[1:]; df['PHYS3G'] = df['PHYS3G'].str.split(')').str[0].astype(int)
df['PHYS3H']=df['PHYS3H'].str[1:]; df['PHYS3H'] = df['PHYS3H'].str.split(')').str[0].astype(int)
df['PHYS3I']=df['PHYS3I'].str[1:]; df['PHYS3I'] = df['PHYS3I'].str.split(')').str[0].astype(int)
df['PHYS3J']=df['PHYS3J'].str[1:]; df['PHYS3J'] = df['PHYS3J'].str.split(')').str[0].astype(int)
df['PHYS3K']=df['PHYS3K'].str[1:]; df['PHYS3K'] = df['PHYS3K'].str.split(')').str[0].astype(int)
df['PHYS3L']=df['PHYS3L'].str[1:]; df['PHYS3L'] = df['PHYS3L'].str.split(')').str[0].astype(int)
df['PHYS3M']=df['PHYS3M'].str[1:]; df['PHYS3M'] = df['PHYS3M'].str.split(')').str[0].astype(int)
df['PHYS4']=df['PHYS4'].str[1:]; df['PHYS4'] = df['PHYS4'].str.split(')').str[0].astype(int)
df['PHYS5']=df['PHYS5'].str[1:]; df['PHYS5'] = df['PHYS5'].str.split(')').str[0].astype(int)
df['PHYS6']=df['PHYS6'].str[1:]; df['PHYS6'] = df['PHYS6'].str.split(')').str[0].astype(int)
df['AGE4']=df['AGE4'].str[1:]; df['AGE4'] = df['AGE4'].str.split(')').str[0].astype(int)
df['AGE7']=df['AGE7'].str[1:]; df['AGE7'] = df['AGE7'].str.split(')').str[0].astype(int)
df['GENDER']=df['GENDER'].str[1:]; df['GENDER'] = df['GENDER'].str.split(')').str[0].astype(int)
df['RACETH']=df['RACETH'].str[1:]; df['RACETH'] = df['RACETH'].str.split(')').str[0].astype(int)
df['RACE_R2']=df['RACE_R2'].str[1:]; df['RACE_R2'] = df['RACE_R2'].str.split(')').str[0].astype(int)
# df['HHINCOME']=df['HHINCOME'].str[1:]; df['HHINCOME'] = df['HHINCOME'].str.split(')').str[0].astype(int)

del df['HHINCOME']

# df['HHINCOME'].replace({'150,000 or more': '1',
#                                '100,000 to under $150,000': '2',
#                                '75,000 to under $100,000': '3',
#                                '50,000 to under $75,000': '4',
#                                '40,000 to under $50,000': '5',
#                                '30,000 to under $40,000': '6',
#                                '20,000 to under $30,000': '7',
#                                '10,000 to under $20,000': '8',
#                                'nder $10,000': '9',
#                                "ON'T KNOW": '77',
#                                'KIPPED ON WEB': '98',
#                                'EFUSED': '99'},
#                               inplace=True)
df['EDUCATION']=df['EDUCATION'].str[1:]; df['EDUCATION'] = df['EDUCATION'].str.split(')').str[0].astype(int)
df['EDUC4']=df['EDUC4'].str[1:]; df['EDUC4'] = df['EDUC4'].str.split(')').str[0].astype(int)
# df['P_OCCUPY2']=df['P_OCCUPY2'].str[1:]; df['P_OCCUPY2'] = df['P_OCCUPY2'].str.split(')').str[0].astype(int)
# df['MARITAL']=df['MARITAL'].str[1:]; df['MARITAL'] = df['MARITAL'].str.split(')').str[0].astype(int)
# df['LGBT']=df['LGBT'].str[1:]; df['LGBT'] = df['LGBT'].str.split(')').str[0].astype(int)
df['HHSIZE1']=df['HHSIZE1'].str[1:]; df['HHSIZE1'] = df['HHSIZE1'].str.split(')').str[0].astype(int)
# df['HH01S']=df['HH01S'].str[1:]; df['HH01S'] = df['HH01S'].str.split(')').str[0].astype(int)
# del df['HH01S']
# df['HH25S']=df['HH25S'].str[1:]; df['HH25S'] = df['HH25S'].str.split(')').str[0].astype(int)
# del df['HH25S']
# df['HH612S']=df['HH612S'].str[1:]; df['HH612S'] = df['HH612S'].str.split(')').str[0].astype(int)
# df['HH1317S']=df['HH1317S'].str[1:]; df['HH1317S'] = df['HH1317S'].str.split(')').str[0].astype(int)
# df['HH18OVS']=df['HH18OVS'].str[1:]; df['HH18OVS'] = df['HH18OVS'].str.split(')').str[0].astype(int)
df['REGION4']=df['REGION4'].str[1:]; df['REGION4'] = df['REGION4'].str.split(')').str[0].astype(int)
df['REGION9']=df['REGION9'].str[1:]; df['REGION9'] = df['REGION9'].str.split(')').str[0].astype(int)
df['P_DENSE']=df['P_DENSE'].str[1:]; df['P_DENSE'] = df['P_DENSE'].str.split(')').str[0].astype(int)
df['MODE']=df['MODE'].str[1:]; df['MODE'] = df['MODE'].str.split(')').str[0].astype(int)
df['LANGUAGE']=df['LANGUAGE'].str[1:]; df['LANGUAGE'] = df['LANGUAGE'].str.split(')').str[0].astype(int)
# df['MAIL50']=df['MAIL50'].str[1:]; df['MAIL50'] = df['MAIL50'].str.split(')').str[0].astype(int)
del df['MAIL50']
del df['RACE1_BANNER']
del df['RACE2_BANNER']
del df['INC_BANNER']
del df['AGE_BANNER']
del df['HH_BANNER']

# df['RACE1_BANNER']=df['RACE1_BANNER'].str[1:]; df['RACE1_BANNER'] = df['RACE1_BANNER'].str.split(')').str[0].astype(int)
# df['RACE2_BANNER']=df['RACE2_BANNER'].str[1:]; df['RACE2_BANNER'] = df['RACE2_BANNER'].str.split(')').str[0].astype(int)
# df['INC_BANNER']=df['INC_BANNER'].str[1:]; df['INC_BANNER'] = df['INC_BANNER'].str.split(')').str[0].astype(int)
# df['AGE_BANNER']=df['AGE_BANNER'].str[1:]; df['AGE_BANNER'] = df['AGE_BANNER'].str.split(')').str[0].astype(int)
# df['HH_BANNER']=df['HH_BANNER'].str[1:]; df['HH_BANNER'] = df['HH_BANNER'].str.split(')').str[0].astype(int)

# %%
# df['RACE1_BANNER'] = df['RACE1_BANNER'].astype(str)
# df['RACE1_BANNER']=df['RACE1_BANNER'].str[1:]; df['RACE1_BANNER'] = df['RACE1_BANNER'].str.split(')').str[0].astype(int)
df['RACE1_BANNER'].value_counts()

# df['HHINCOME'].replace({'150,000 or more': '1',
#                                '100,000 to under $150,000': '2',
#                                '75,000 to under $100,000': '3',
#                                '50,000 to under $75,000': '4',
#                                '40,000 to under $50,000': '5',
#                                '30,000 to under $40,000': '6',
#                                '20,000 to under $30,000': '7',
#                                '10,000 to under $20,000': '8',
#                                'nder $10,000': '9',
#                                "ON'T KNOW": '77',
#                                'KIPPED ON WEB': '98',
#                                'EFUSED': '99'},
#                               inplace=True)
# Out:
# (1) NH white 5                      5976
# (88) Removed for disclosure risk     813
# (2) NH black 5                       796
# (3) Hispanic 5                       755
# (5) NH Other 5                       333
# (4) NH Asian 5                       291
# Name: RACE1_BANNER, dtype: int64

# %%
#CONVERTING CATEGORICAL TO NUMERICAL DATA USING GET_DUMMIES
import pandas as pd
# df=pd.get_dummies(df,columns=['COLUMN_A'])
# df=pd.get_dummies(df,columns=['SU_ID'])
df=pd.get_dummies(df,columns=['P_PANEL'])
# df=pd.get_dummies(df,columns=['NATIONAL_WEIGHT'])
# df=pd.get_dummies(df,columns=['REGION_WEIGHT'])
# df=pd.get_dummies(df,columns=['NATIONAL_WEIGHT_POP'])
# df=pd.get_dummies(df,columns=['REGION_WEIGHT_POP'])
# df=pd.get_dummies(df,columns=['NAT_WGT_COMB_POP'])
# df=pd.get_dummies(df,columns=['REG_WGT_COMB_POP'])
# df=pd.get_dummies(df,columns=['P_GEO'])
df=pd.get_dummies(df,columns=['SOC1'])
df=pd.get_dummies(df,columns=['SOC2A'])
df=pd.get_dummies(df,columns=['SOC2B'])
df=pd.get_dummies(df,columns=['SOC3A'])
df=pd.get_dummies(df,columns=['SOC3B'])
df=pd.get_dummies(df,columns=['SOC4A'])
df=pd.get_dummies(df,columns=['SOC4B'])
df=pd.get_dummies(df,columns=['PHYS8'])
df=pd.get_dummies(df,columns=['PHYS1A'])
df=pd.get_dummies(df,columns=['PHYS1B'])
df=pd.get_dummies(df,columns=['PHYS1C'])
df=pd.get_dummies(df,columns=['PHYS1D'])
df=pd.get_dummies(df,columns=['PHYS1E'])
df=pd.get_dummies(df,columns=['PHYS1F'])
df=pd.get_dummies(df,columns=['PHYS1G'])
df=pd.get_dummies(df,columns=['PHYS1H'])
df=pd.get_dummies(df,columns=['PHYS1I'])
df=pd.get_dummies(df,columns=['PHYS1J'])
df=pd.get_dummies(df,columns=['PHYS1K'])
df=pd.get_dummies(df,columns=['PHYS1L'])
df=pd.get_dummies(df,columns=['PHYS1M'])
df=pd.get_dummies(df,columns=['PHYS1N'])
df=pd.get_dummies(df,columns=['PHYS1O'])
df=pd.get_dummies(df,columns=['PHYS1P'])
df=pd.get_dummies(df,columns=['PHYS1Q'])
df=pd.get_dummies(df,columns=['SOC5A'])
df=pd.get_dummies(df,columns=['SOC5B'])
df=pd.get_dummies(df,columns=['SOC5C'])
df=pd.get_dummies(df,columns=['SOC5D'])
df=pd.get_dummies(df,columns=['SOC5E'])
df=pd.get_dummies(df,columns=['PHYS2_1'])
df=pd.get_dummies(df,columns=['PHYS2_2'])
df=pd.get_dummies(df,columns=['PHYS2_3'])
df=pd.get_dummies(df,columns=['PHYS2_4'])
df=pd.get_dummies(df,columns=['PHYS2_5'])
df=pd.get_dummies(df,columns=['PHYS2_6'])
df=pd.get_dummies(df,columns=['PHYS2_7'])
df=pd.get_dummies(df,columns=['PHYS2_8'])
df=pd.get_dummies(df,columns=['PHYS2_9'])
df=pd.get_dummies(df,columns=['PHYS2_10'])
df=pd.get_dummies(df,columns=['PHYS2_11'])
df=pd.get_dummies(df,columns=['PHYS2_12'])
df=pd.get_dummies(df,columns=['PHYS2_13'])
df=pd.get_dummies(df,columns=['PHYS2_14'])
df=pd.get_dummies(df,columns=['PHYS2_15'])
df=pd.get_dummies(df,columns=['PHYS2_16'])
df=pd.get_dummies(df,columns=['PHYS2_17'])
df=pd.get_dummies(df,columns=['PHYS2_18'])
df=pd.get_dummies(df,columns=['PHYS2_19'])
df=pd.get_dummies(df,columns=['PHYS2_DK'])
df=pd.get_dummies(df,columns=['PHYS2_SKP'])
df=pd.get_dummies(df,columns=['PHYS2_REF'])
df=pd.get_dummies(df,columns=['PHYS10A'])
df=pd.get_dummies(df,columns=['PHYS10B'])
df=pd.get_dummies(df,columns=['PHYS10C'])
df=pd.get_dummies(df,columns=['PHYS10D'])
df=pd.get_dummies(df,columns=['PHYS10E'])
df=pd.get_dummies(df,columns=['ECON8A'])
df=pd.get_dummies(df,columns=['ECON8B'])
df=pd.get_dummies(df,columns=['ECON8C'])
df=pd.get_dummies(df,columns=['ECON8D'])
df=pd.get_dummies(df,columns=['ECON8E'])
df=pd.get_dummies(df,columns=['ECON8F'])
df=pd.get_dummies(df,columns=['ECON8G'])
df=pd.get_dummies(df,columns=['ECON8H'])
df=pd.get_dummies(df,columns=['ECON8I'])
df=pd.get_dummies(df,columns=['ECON8J'])
df=pd.get_dummies(df,columns=['ECON8K'])
df=pd.get_dummies(df,columns=['ECON8L'])
df=pd.get_dummies(df,columns=['ECON8M'])
df=pd.get_dummies(df,columns=['ECON8N'])
df=pd.get_dummies(df,columns=['ECON8O'])
df=pd.get_dummies(df,columns=['ECON8P'])
df=pd.get_dummies(df,columns=['ECON8Q'])
df=pd.get_dummies(df,columns=['ECON8R'])
df=pd.get_dummies(df,columns=['ECON8S'])
df=pd.get_dummies(df,columns=['ECON7_1'])
df=pd.get_dummies(df,columns=['ECON7_2'])
df=pd.get_dummies(df,columns=['ECON7_3'])
df=pd.get_dummies(df,columns=['ECON7_4'])
df=pd.get_dummies(df,columns=['ECON7_5'])
df=pd.get_dummies(df,columns=['ECON7_6'])
df=pd.get_dummies(df,columns=['ECON7_7'])
df=pd.get_dummies(df,columns=['ECON7_8'])
df=pd.get_dummies(df,columns=['ECON7_DK'])
df=pd.get_dummies(df,columns=['ECON7_SKP'])
df=pd.get_dummies(df,columns=['ECON7_REF'])
df=pd.get_dummies(df,columns=['ECON1'])
# df=pd.get_dummies(df,columns=['ECON2'])
# df=pd.get_dummies(df,columns=['ECON4'])
df=pd.get_dummies(df,columns=['ECON3'])
df=pd.get_dummies(df,columns=['ECON4A'])
df=pd.get_dummies(df,columns=['ECON4B'])
df=pd.get_dummies(df,columns=['ECON6A'])
df=pd.get_dummies(df,columns=['ECON6B'])
df=pd.get_dummies(df,columns=['ECON6C'])
df=pd.get_dummies(df,columns=['ECON6D'])
df=pd.get_dummies(df,columns=['ECON6E'])
df=pd.get_dummies(df,columns=['ECON6F'])
df=pd.get_dummies(df,columns=['ECON6G'])
df=pd.get_dummies(df,columns=['ECON6H'])
df=pd.get_dummies(df,columns=['ECON6I'])
df=pd.get_dummies(df,columns=['ECON6J'])
df=pd.get_dummies(df,columns=['ECON6K'])
df=pd.get_dummies(df,columns=['ECON6L'])
df=pd.get_dummies(df,columns=['ECON5A_A'])
df=pd.get_dummies(df,columns=['ECON5A_B'])
df=pd.get_dummies(df,columns=['PHYS7_1'])
df=pd.get_dummies(df,columns=['PHYS7_2'])
df=pd.get_dummies(df,columns=['PHYS7_3'])
df=pd.get_dummies(df,columns=['PHYS7_4'])
df=pd.get_dummies(df,columns=['PHYS7_DK'])
df=pd.get_dummies(df,columns=['PHYS7_SKP'])
df=pd.get_dummies(df,columns=['PHYS7_REF'])
df=pd.get_dummies(df,columns=['PHYS11'])
# df=pd.get_dummies(df,columns=['PHYS11_TEMP'])
df=pd.get_dummies(df,columns=['PHYS9A'])
df=pd.get_dummies(df,columns=['PHYS9B'])
df=pd.get_dummies(df,columns=['PHYS9C'])
df=pd.get_dummies(df,columns=['PHYS9D'])
df=pd.get_dummies(df,columns=['PHYS9E'])
df=pd.get_dummies(df,columns=['PHYS9F'])
df=pd.get_dummies(df,columns=['PHYS9G'])
df=pd.get_dummies(df,columns=['PHYS9H'])
df=pd.get_dummies(df,columns=['PHYS3A'])
df=pd.get_dummies(df,columns=['PHYS3B'])
df=pd.get_dummies(df,columns=['PHYS3C'])
df=pd.get_dummies(df,columns=['PHYS3D'])
df=pd.get_dummies(df,columns=['PHYS3E'])
df=pd.get_dummies(df,columns=['PHYS3F'])
df=pd.get_dummies(df,columns=['PHYS3G'])
df=pd.get_dummies(df,columns=['PHYS3H'])
df=pd.get_dummies(df,columns=['PHYS3I'])
df=pd.get_dummies(df,columns=['PHYS3J'])
df=pd.get_dummies(df,columns=['PHYS3K'])
df=pd.get_dummies(df,columns=['PHYS3L'])
df=pd.get_dummies(df,columns=['PHYS3M'])
df=pd.get_dummies(df,columns=['PHYS4'])
df=pd.get_dummies(df,columns=['PHYS5'])
df=pd.get_dummies(df,columns=['PHYS6'])
df=pd.get_dummies(df,columns=['AGE4'])
df=pd.get_dummies(df,columns=['AGE7'])
df=pd.get_dummies(df,columns=['GENDER'])
df=pd.get_dummies(df,columns=['RACETH'])
df=pd.get_dummies(df,columns=['RACE_R2'])
df=pd.get_dummies(df,columns=['HHINCOME'])
df=pd.get_dummies(df,columns=['EDUCATION'])
df=pd.get_dummies(df,columns=['EDUC4'])
# df=pd.get_dummies(df,columns=['P_OCCUPY2'])
# df=pd.get_dummies(df,columns=['MARITAL'])
# df=pd.get_dummies(df,columns=['LGBT'])
df=pd.get_dummies(df,columns=['HHSIZE1'])
df=pd.get_dummies(df,columns=['HH01S'])
df=pd.get_dummies(df,columns=['HH25S'])
df=pd.get_dummies(df,columns=['HH612S'])
df=pd.get_dummies(df,columns=['HH1317S'])
df=pd.get_dummies(df,columns=['HH18OVS'])
df=pd.get_dummies(df,columns=['REGION4'])
df=pd.get_dummies(df,columns=['REGION9'])
df=pd.get_dummies(df,columns=['P_DENSE'])
df=pd.get_dummies(df,columns=['MODE'])
df=pd.get_dummies(df,columns=['LANGUAGE'])
# df=pd.get_dummies(df,columns=['MAIL50'])
# df=pd.get_dummies(df,columns=['RACE1_BANNER'])
# df=pd.get_dummies(df,columns=['RACE2_BANNER'])
# df=pd.get_dummies(df,columns=['INC_BANNER'])
# df=pd.get_dummies(df,columns=['AGE_BANNER'])
# df=pd.get_dummies(df,columns=['HH_BANNER'])

df

# %%
#EXPORTING CLEANED DATASET
from pathlib import Path
filepath = Path('C:\python\cleaned_dataset3.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(filepath)
